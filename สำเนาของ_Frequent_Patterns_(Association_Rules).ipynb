# %% [markdown]
# <a href="https://colab.research.google.com/github/Pimchanok6430205105/BSC_DPDM23/blob/main/%E0%B8%AA%E0%B8%B3%E0%B9%80%E0%B8%99%E0%B8%B2%E0%B8%82%E0%B8%AD%E0%B8%87_Frequent_Patterns_(Association_Rules).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/MyDrive/BSC_DPDM23'
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv(os.path.join(path,'/content/drive/MyDrive/BSC_DPDM23/reduced_marketbasket.csv'),encoding='latin-1')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom
# ...                  ...        ...         ...             ...
# 541904  12/09/2011 12:50       0.85     12680.0          France
# 541905  12/09/2011 12:50       2.10     12680.0          France
# 541906  12/09/2011 12:50       4.15     12680.0          France
# 541907  12/09/2011 12:50       4.15     12680.0          France
# 541908  12/09/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# ##แปลง data ให้อยู่ในรูปแบบ Transaction data ด้วย Groupby.apply(list)

# %%
data.groupby('InvoiceNo')['StockCode'].apply(list)
# Out:
# InvoiceNo
# 536365     [85123A, 71053, 84406B, 84029G, 84029E, 22752,...
# 536366                                        [22633, 22632]
# 536367     [84879, 22745, 22748, 22749, 22310, 84969, 226...
# 536368                          [22960, 22913, 22912, 22914]
# 536369                                               [21756]
#                                  ...
# C581484                                              [23843]
# C581490                                       [22178, 23144]
# C581499                                                  [M]
# C581568                                              [21258]
# C581569                                       [84978, 20979]
# Name: StockCode, Length: 25900, dtype: object

# %%
transactions = data.groupby('InvoiceNo')['StockCode'].apply(list)

# %%
data.shape
# Out:
# (541909, 8)

# %% [markdown]
# ###Quiz หาว่ามีกี่ประเทศ

# %%
data['Country'].value_counts().shape
# Out:
# (38,)

# %% [markdown]
# ## Association Rules

# %%
# !pip install apyori
# Out:
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5954 sha256=b4a296898e6c79b879c6a0c8c0f5540895013e439f5d2604a58e136657c54c4e
#   Stored in directory: /root/.cache/pip/wheels/c4/1a/79/20f55c470a50bb3702a8cb7c94d8ada15573538c7f4baebe2d
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
from apyori import apriori

# %%
frequentItemsets = list(apriori(transactions,min_support = 0.065))
frequentItemsets
# Out:
# [RelationRecord(items=frozenset({'22423'}), support=0.08386100386100385, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22423'}), confidence=0.08386100386100385, lift=1.0)]),
#  RelationRecord(items=frozenset({'47566'}), support=0.06586872586872587, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'47566'}), confidence=0.06586872586872587, lift=1.0)]),
#  RelationRecord(items=frozenset({'85099B'}), support=0.08243243243243244, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85099B'}), confidence=0.08243243243243244, lift=1.0)]),
#  RelationRecord(items=frozenset({'85123A'}), support=0.08671814671814672, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85123A'}), confidence=0.08671814671814672, lift=1.0)])]

# %%
len(frequentItemsets)
# Out:
# 4

# %%
frequentItemsets[0][0]
# Out:
# frozenset({'22423'})

# %%
dir(frequentItemsets[0][0])
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'copy',
#  'difference',
#  'intersection',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'symmetric_difference',
#  'union']

# %%
frequentItemsets[0][0].__len__()
# Out:
# 1

# %%
min_sup = 0.03

frequentItemsets = list(apriori(transactions,min_support = min_sup))
for i in frequentItemsets:
    if i[0].__len__()>1:
        print('yes')
        print(i)
# Out:
# yes
# RelationRecord(items=frozenset({'85099B', '22386'}), support=0.03216216216216216, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85099B', '22386'}), confidence=0.03216216216216216, lift=1.0), OrderedStatistic(items_base=frozenset({'22386'}), items_add=frozenset({'85099B'}), confidence=0.6766856214459789, lift=8.20897311262335), OrderedStatistic(items_base=frozenset({'85099B'}), items_add=frozenset({'22386'}), confidence=0.39016393442622943, lift=8.20897311262335)])
# yes
# RelationRecord(items=frozenset({'22697', '22699'}), support=0.03027027027027027, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22697', '22699'}), confidence=0.03027027027027027, lift=1.0), OrderedStatistic(items_base=frozenset({'22697'}), items_add=frozenset({'22699'}), confidence=0.7417218543046358, lift=17.1523178807947), OrderedStatistic(items_base=frozenset({'22699'}), items_add=frozenset({'22697'}), confidence=0.7, lift=17.1523178807947)])

# %% [markdown]
# RelationRecord(items=frozenset({'22386', '85099B'}),
#
# support=0.03216216216216216,
#
# ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22386', '85099B'}), confidence=0.03216216216216216, lift=1.0),
#
# OrderedStatistic(items_base=frozenset({'22386'}), items_add=frozenset({'85099B'}), confidence=0.6766856214459789, lift=8.20897311262335),
#
# OrderedStatistic(items_base=frozenset({'85099B'}), items_add=frozenset({'22386'}), confidence=0.39016393442622943, lift=8.20897311262335)])

# %%
set(data[(data['StockCode']=='22386') | (data['StockCode']=='85099B') | (data['StockCode']=='22699') | (data['StockCode']=='22697') ]['Description'])
# Out:
# {'GREEN REGENCY TEACUP AND SAUCER',
#  'JUMBO BAG PINK POLKADOT',
#  'JUMBO BAG RED RETROSPOT',
#  'ROSES REGENCY TEACUP AND SAUCER '}

# %% [markdown]
# RelationRecord(items=frozenset({'22699', '22697'}), support=0.03027027027027027,
#
# ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22699', '22697'}), confidence=0.03027027027027027, lift=1.0),
#
# OrderedStatistic(items_base=frozenset({'22697'}), items_add=frozenset({'22699'}), confidence=0.7417218543046358, lift=17.1523178807947),
#
# OrderedStatistic(items_base=frozenset({'22699'}), items_add=frozenset({'22697'}), confidence=0.7, lift=17.1523178807947)])

# %%
set(data[(data['StockCode']=='22699') | (data['StockCode']=='22697')]['InvoiceNo'])
# Out:
# {'562717',
#  '543045',
#  '564817',
#  '561637',
#  '566193',
#  '568060',
#  '564092',
#  '551997',
#  '558862',
#  '571713',
#  '537240',
#  '542619',
#  '567293',
#  '537396',
#  '579187',
#  '549222',
#  '564835',
#  '555722',
#  '546136',
#  '558120',
#  'C539071',
#  '578817',
#  '575703',
#  '578067',
#  '576202',
#  '558116',
#  '546660',
#  '571034',
#  '539594',
#  '539609',
#  '548987',
#  '560246',
#  'C545033',
#  '545428',
#  '549951',
#  '560473',
#  'C545438',
#  '546896',
#  '556206',
#  '562711',
#  '553891',
#  '540499',
#  '543107',
#  '573585',
#  '553035',
#  '555851',
#  '562282',
#  '565150',
#  '541960',
#  '545411',
#  '564191',
#  '554013',
#  '541584',
#  '545216',
#  '553542',
#  'C579945',
#  '563166',
#  '545895',
#  '552956',
#  '559055',
#  '538566',
#  '550986',
#  '562607',
#  '551387',
#  '548260',
#  '542349',
#  '569834',
#  '567671',
#  '552867',
#  '571061',
#  '572854',
#  '538370',
#  '559817',
#  '552563',
#  '545214',
#  '552694',
#  '561891',
#  '539735',
#  '544660',
#  '543989',
#  '573020',
#  '576246',
#  '537642',
#  '555106',
#  '573388',
#  'C555409',
#  '560826',
#  '564057',
#  '537179',
#  '565396',
#  '564056',
#  '575221',
#  '569737',
#  'C545444',
#  '561089',
#  '580729',
#  '568057',
#  '540848',
#  '546314',
#  '548003',
#  '551062',
#  '571550',
#  '545377',
#  '566400',
#  '579503',
#  '538903',
#  '552247',
#  '558885',
#  '537434',
#  '553684',
#  '552710',
#  '550470',
#  '544684',
#  '550458',
#  '560291',
#  '537254',
#  '538177',
#  '558873',
#  '556237',
#  '541423',
#  '554842',
#  '553162',
#  '562950',
#  '558119',
#  '580501',
#  '553461',
#  '556256',
#  'C542912',
#  '558565',
#  '560036',
#  '540259',
#  '577400',
#  'C565848',
#  '550437',
#  '556917',
#  '572212',
#  '536623',
#  '536980',
#  'C564964',
#  '563910',
#  '572758',
#  '558702',
#  '543530',
#  '561329',
#  '542344',
#  '572229',
#  '546683',
#  '544067',
#  '564432',
#  '556083',
#  'C566758',
#  '553369',
#  '559930',
#  '537887',
#  'C537834',
#  '550213',
#  '571714',
#  '547826',
#  '567905',
#  '575947',
#  '550307',
#  '574739',
#  '562202',
#  '552323',
#  '539752',
#  '544201',
#  '577078',
#  '568411',
#  '544095',
#  '537645',
#  '561933',
#  '563353',
#  'C560560',
#  '573580',
#  '555871',
#  '548983',
#  '541859',
#  '550503',
#  '567378',
#  '556284',
#  '559639',
#  '549750',
#  '567341',
#  '541969',
#  '544824',
#  '551995',
#  '544677',
#  '557145',
#  '559938',
#  '571797',
#  '555109',
#  '544887',
#  '552857',
#  '562417',
#  '545812',
#  '545445',
#  '570834',
#  '560590',
#  '574893',
#  '548192',
#  '549525',
#  '574334',
#  '568310',
#  '551564',
#  '560604',
#  '541949',
#  '549124',
#  '548191',
#  '561894',
#  '558443',
#  '540992',
#  '552663',
#  '568988',
#  'C558255',
#  'C577752',
#  '551657',
#  '581023',
#  '544664',
#  '558372',
#  '552324',
#  '569888',
#  '552975',
#  '562264',
#  '554329',
#  '551960',
#  '556073',
#  '540364',
#  '565724',
#  '545426',
#  'C555254',
#  '544305',
#  '566577',
#  '575620',
#  '537643',
#  '536523',
#  'C566167',
#  '551160',
#  '559693',
#  '546669',
#  '552540',
#  '570597',
#  '550186',
#  '555925',
#  '569246',
#  '565424',
#  '551014',
#  'C545525',
#  '542664',
#  '549305',
#  '560780',
#  '567793',
#  '543036',
#  '581345',
#  '542717',
#  '561645',
#  '563505',
#  '537823',
#  '551717',
#  '563384',
#  '547248',
#  '548648',
#  '562377',
#  '564199',
#  '554704',
#  '545022',
#  '551944',
#  '561070',
#  '550025',
#  '575484',
#  'C564212',
#  '555836',
#  '549524',
#  '581219',
#  '540646',
#  '545721',
#  'C551511',
#  '538851',
#  '561651',
#  '547788',
#  '546643',
#  '573553',
#  '537385',
#  '580665',
#  '567157',
#  '568955',
#  '571746',
#  '537738',
#  '553946',
#  '572028',
#  '578833',
#  '547846',
#  '541133',
#  '548860',
#  '548894',
#  '566597',
#  '548974',
#  '550205',
#  '554557',
#  '562219',
#  '563613',
#  '545215',
#  '572553',
#  '566221',
#  '545333',
#  '567128',
#  'C550648',
#  'C545449',
#  '568792',
#  '541130',
#  '570650',
#  '543923',
#  '562934',
#  '565151',
#  '577020',
#  '560976',
#  '551286',
#  'C541693',
#  '555499',
#  '575866',
#  '539736',
#  '542719',
#  '563569',
#  '565748',
#  'C569114',
#  '565840',
#  '572751',
#  '570488',
#  '568199',
#  '555277',
#  '536946',
#  '552257',
#  '552662',
#  '553709',
#  '541783',
#  'C569911',
#  'C546865',
#  '536627',
#  '559923',
#  'C554330',
#  '578943',
#  '546158',
#  '549730',
#  '560895',
#  '547400',
#  '565120',
#  '568651',
#  '563534',
#  '557494',
#  '565994',
#  '544940',
#  '545526',
#  '548516',
#  '549909',
#  '552614',
#  '553385',
#  '544893',
#  '537378',
#  '556205',
#  '538880',
#  '579012',
#  '549999',
#  '548919',
#  '566731',
#  '541129',
#  '572550',
#  '576644',
#  '581492',
#  '560398',
#  '569650',
#  '575176',
#  '546212',
#  '544456',
#  '569568',
#  '566326',
#  '544565',
#  '550519',
#  '555870',
#  'C544665',
#  '552336',
#  '559295',
#  '546891',
#  '572066',
#  '543660',
#  '565841',
#  '538371',
#  'C555358',
#  '549595',
#  '551088',
#  '545036',
#  '576063',
#  '574731',
#  '540664',
#  '549425',
#  '543546',
#  '572552',
#  '570086',
#  '546892',
#  '540981',
#  '561125',
#  '568908',
#  '575930',
#  '550201',
#  '581122',
#  '564754',
#  '544681',
#  '568193',
#  '541424',
#  '550333',
#  '540154',
#  '558918',
#  '560772',
#  '567663',
#  '557259',
#  '542779',
#  '554714',
#  '578044',
#  'C558434',
#  '580983',
#  '561455',
#  '552642',
#  '551414',
#  'C566084',
#  '537335',
#  '543533',
#  '566290',
#  '544339',
#  '551775',
#  '573083',
#  '567631',
#  '554030',
#  '548522',
#  '555276',
#  '540372',
#  '568781',
#  '570713',
#  '571216',
#  '557616',
#  '554110',
#  '571446',
#  '557500',
#  '559493',
#  '573266',
#  '567922',
#  '575932',
#  'C559667',
#  '563896',
#  '549056',
#  '559510',
#  '563614',
#  '562534',
#  '554337',
#  '551005',
#  '544569',
#  '567639',
#  '578844',
#  '555327',
#  '551343',
#  '551599',
#  '553869',
#  '553607',
#  'C558312',
#  '574856',
#  '544301',
#  '548673',
#  '565862',
#  '581217',
#  '546837',
#  '558073',
#  '551174',
#  '566981',
#  '544749',
#  '578827',
#  '552149',
#  '544186',
#  '546888',
#  '573397',
#  '553541',
#  '553578',
#  '541506',
#  '569555',
#  '536592',
#  '541576',
#  'C556793',
#  '566477',
#  '577594',
#  '557431',
#  '580610',
#  '575875',
#  '576388',
#  '556459',
#  '579445',
#  '542115',
#  '581006',
#  '569918',
#  '556243',
#  '567886',
#  '559497',
#  '563931',
#  '556826',
#  '559557',
#  '563193',
#  '556264',
#  'C574548',
#  '541866',
#  '539738',
#  '553202',
#  '555015',
#  '546007',
#  '537237',
#  '552259',
#  '536856',
#  '545014',
#  '543485',
#  '548194',
#  '561714',
#  'C548485',
#  '557788',
#  '546980',
#  'C545828',
#  '561217',
#  '545701',
#  '547964',
#  '541497',
#  '574328',
#  '547828',
#  '545078',
#  '565779',
#  '578347',
#  '573778',
#  '566396',
#  '562222',
#  '548893',
#  '538862',
#  'C545724',
#  '558066',
#  '545475',
#  'C545456',
#  '556927',
#  '565916',
#  '558475',
#  '553575',
#  '558683',
#  '562843',
#  '541008',
#  '573511',
#  '574561',
#  '545945',
#  '578031',
#  '556812',
#  '543973',
#  '563549',
#  '548163',
#  '560580',
#  '579267',
#  '540662',
#  '567368',
#  '578993',
#  '557301',
#  '581059',
#  '560777',
#  '579927',
#  'C537853',
#  '544207',
#  '555647',
#  '567873',
#  '537022',
#  '537688',
#  '579572',
#  '538071',
#  '552804',
#  '563951',
#  '553768',
#  '556095',
#  '577316',
#  '546442',
#  '556082',
#  '546752',
#  '546545',
#  '551550',
#  '563584',
#  '553546',
#  '545020',
#  '548768',
#  '557672',
#  '565726',
#  '573338',
#  '549997',
#  '571433',
#  '547206',
#  '549295',
#  '542221',
#  '545543',
#  '544434',
#  '564975',
#  '544081',
#  '575946',
#  '569570',
#  '548896',
#  '543532',
#  '541110',
#  '581498',
#  '550638',
#  '554798',
#  '544421',
#  '547841',
#  '579751',
#  '570227',
#  '561355',
#  '569419',
#  '539635',
#  '546884',
#  '579297',
#  '557481',
#  '570127',
#  '573320',
#  '539593',
#  '550899',
#  '546927',
#  '570428',
#  '551825',
#  '565838',
#  '580774',
#  '578149',
#  '568574',
#  '556323',
#  '551953',
#  '550613',
#  '570677',
#  '543370',
#  '537313',
#  '554028',
#  '564184',
#  '558348',
#  '553766',
#  '559878',
#  '543019',
#  '561698',
#  '577071',
#  '566624',
#  '558262',
#  '557782',
#  '536524',
#  '557642',
#  '565155',
#  'C555598',
#  '556434',
#  '578065',
#  '572655',
#  '550125',
#  '568676',
#  '545696',
#  '550471',
#  '543826',
#  '548808',
#  '565919',
#  'C538124',
#  '551340',
#  '559489',
#  '544075',
#  '556016',
#  '543467',
#  '545474',
#  '580367',
#  '552302',
#  '543188',
#  '579711',
#  '558774',
#  '542729',
#  '557493',
#  '580053',
#  '575742',
#  '556821',
#  '545343',
#  '541530',
#  '554935',
#  'C561232',
#  '580066',
#  '554813',
#  '555854',
#  'C542413',
#  '562420',
#  '548663',
#  '548159',
#  '574707',
#  '544778',
#  '553543',
#  '544768',
#  '543399',
#  '555594',
#  '568804',
#  '539468',
#  '562113',
#  '545719',
#  '544208',
#  '579518',
#  '545601',
#  '553210',
#  '549192',
#  '547250',
#  '577531',
#  '566976',
#  '569496',
#  '542629',
#  '567673',
#  '555743',
#  '538660',
#  '537638',
#  '567280',
#  '544833',
#  '562273',
#  '577258',
#  '575138',
#  '543486',
#  '547378',
#  '581238',
#  '562157',
#  '572613',
#  '546760',
#  '577518',
#  '554921',
#  'C564854',
#  '557502',
#  '542999',
#  '555524',
#  '554415',
#  '563442',
#  '580098',
#  '539739',
#  '540352',
#  '547042',
#  '545320',
#  '559173',
#  '565117',
#  '566124',
#  '550958',
#  '542632',
#  '544574',
#  '549052',
#  '562166',
#  '564172',
#  '577355',
#  '558770',
#  '553387',
#  '562429',
#  '571560',
#  '538951',
#  '576329',
#  '556767',
#  '543022',
#  '551057',
#  '566583',
#  '545429',
#  '546915',
#  '555400',
#  '548547',
#  '581472',
#  '548559',
#  '564300',
#  '575846',
#  '579777',
#  '539437',
#  '553013',
#  '567670',
#  '563023',
#  '537666',
#  '577039',
#  'C550808',
#  '538148',
#  'C555253',
#  '558904',
#  '576618',
#  '568134',
#  '564221',
#  '557605',
#  '552664',
#  '559134',
#  '552730',
#  '575739',
#  '544837',
#  '559337',
#  '559052',
#  '547107',
#  '543116',
#  '580667',
#  '567140',
#  '539451',
#  'C556880',
#  '549587',
#  '554098',
#  '562770',
#  '568048',
#  '547547',
#  '579512',
#  '543277',
#  '569374',
#  '570258',
#  '571441',
#  'C578144',
#  '542389',
#  '556501',
#  '554036',
#  '544205',
#  '554382',
#  '541811',
#  '580526',
#  '565214',
#  '556415',
#  '548514',
#  '561209',
#  '576616',
#  '551334',
#  '549927',
#  '554326',
#  '544920',
#  '571058',
#  '555278',
#  '569917',
#  '565849',
#  '554643',
#  '557645',
#  '580115',
#  '548210',
#  '543251',
#  '555510',
#  '580673',
#  '542087',
#  '547498',
#  '561820',
#  '577512',
#  '543097',
#  '572035',
#  '540005',
#  '579539',
#  '568567',
#  '577029',
#  '551173',
#  '579471',
#  '558103',
#  '564091',
#  '566257',
#  'C540393',
#  '547936',
#  '554310',
#  '550499',
#  '557560',
#  '556259',
#  '566607',
#  '557621',
#  '552533',
#  '548733',
#  '578314',
#  '550953',
#  '551058',
#  '547967',
#  '578949',
#  '541421',
#  '553612',
#  '561095',
#  '550210',
#  '554054',
#  '558681',
#  '556783',
#  'C553479',
#  '558035',
#  '569544',
#  '557211',
#  '539737',
#  '573822',
#  '543201',
#  '543626',
#  'C562375',
#  '570701',
#  '563922',
#  '564820',
#  '573125',
#  '544314',
#  'C556635',
#  '574298',
#  '579508',
#  '554158',
#  '574950',
#  '565331',
#  '571508',
#  '571377',
#  '565286',
#  '570388',
#  'C560588',
#  '578331',
#  '540465',
#  '562713',
#  '566600',
#  '578344',
#  '548373',
#  '558777',
#  '551994',
#  '554974',
#  '566060',
#  '543754',
#  '540418',
#  '563076',
#  '559886',
#  '560209',
#  '543487',
#  '566482',
#  'C567955',
#  '555275',
#  '555488',
#  '545464',
#  '560790',
#  '546498',
#  '561394',
#  '544089',
#  '572549',
#  '544888',
#  '555574',
#  '545467',
#  '555630',
#  '553870',
#  '544055',
#  '566602',
#  '571745',
#  '567184',
#  '545340',
#  '563477',
#  '566559',
#  '540464',
#  '540026',
#  '549746',
#  '550251',
#  '575515',
#  '544338',
#  '547386',
#  '571546',
#  '562849',
#  '538524',
#  '568333',
#  '576381',
#  '538153',
#  '540777',
#  '548718',
#  '537754',
#  '570688',
#  '554958',
#  '581439',
#  '546562',
#  'C546125',
#  '558240',
#  '550500',
#  '566572',
#  '573576',
#  '559525',
#  '566720',
#  '552232',
#  '545154',
#  '556813',
#  '540907',
#  'C541822',
#  '568553',
#  '571937',
#  '545058',
#  '559906',
#  '576840',
#  '560906',
#  '563561',
#  '545690',
#  '577298',
#  '565223',
#  '568654',
#  '566603',
#  '552315',
#  '558089',
#  '566255',
#  '552196',
#  '539442',
#  '548158',
#  '572082',
#  '566094',
#  '576837',
#  'C538059',
#  '543106',
#  '542862',
#  '561051',
#  '570187',
#  '571305',
#  '561236',
#  '541999',
#  '579093',
#  '550978',
#  '542527',
#  '549435',
#  '556577',
#  '567507',
#  '555486',
#  '561702',
#  '566395',
#  '553191',
#  '558526',
#  '549294',
#  '550474',
#  '558068',
#  ...}

# %%
data[data['InvoiceNo']=='562950']
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 297488    562950     22752        SET 7 BABUSHKA NESTING BOXES         2
# 297489    562950     22755     SMALL PURPLE BABUSHKA NOTEBOOK         12
# 297490    562950     22753     SMALL YELLOW BABUSHKA NOTEBOOK         12
# 297491    562950     22754        SMALL RED BABUSHKA NOTEBOOK         12
# 297492    562950     22757        LARGE RED BABUSHKA NOTEBOOK         12
# 297493    562950     22758    LARGE PURPLE BABUSHKA NOTEBOOK          12
# 297494    562950     22756     LARGE YELLOW BABUSHKA NOTEBOOK         12
# 297495    562950     23310             BUBBLEGUM RING ASSORTED        36
# 297496    562950     23280  FOLDING BUTTERFLY MIRROR HOT PINK         12
# 297497    562950     22383              LUNCH BAG SUKI DESIGN         10
# 297498    562950     22492             MINI PAINT SET VINTAGE         36
# 297499    562950     71459      HANGING JAM JAR T-LIGHT HOLDER        12
# 297500    562950     84945  MULTI COLOUR SILVER T-LIGHT HOLDER        12
# 297501    562950     21175         GIN + TONIC DIET METAL SIGN        12
# 297502    562950     23164                  REGENCY CAKE SLICE         4
# 297503    562950     23245          SET OF 3 REGENCY CAKE TINS         4
# 297504    562950     23171            REGENCY TEA PLATE GREEN         12
# 297505    562950     22697     GREEN REGENCY TEACUP AND SAUCER         6
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 297488  08/11/2011 09:56       8.50     15608.0  United Kingdom
# 297489  08/11/2011 09:56       0.85     15608.0  United Kingdom
# 297490  08/11/2011 09:56       0.85     15608.0  United Kingdom
# 297491  08/11/2011 09:56       0.85     15608.0  United Kingdom
# 297492  08/11/2011 09:56       1.25     15608.0  United Kingdom
# 297493  08/11/2011 09:56       1.25     15608.0  United Kingdom
# 297494  08/11/2011 09:56       1.25     15608.0  United Kingdom
# 297495  08/11/2011 09:56       0.42     15608.0  United Kingdom
# 297496  08/11/2011 09:56       0.83     15608.0  United Kingdom
# 297497  08/11/2011 09:56       1.65     15608.0  United Kingdom
# 297498  08/11/2011 09:56       0.65     15608.0  United Kingdom
# 297499  08/11/2011 09:56       0.85     15608.0  United Kingdom
# 297500  08/11/2011 09:56       0.85     15608.0  United Kingdom
# 297501  08/11/2011 09:56       2.55     15608.0  United Kingdom
# 297502  08/11/2011 09:56       4.95     15608.0  United Kingdom
# 297503  08/11/2011 09:56       4.95     15608.0  United Kingdom
# 297504  08/11/2011 09:56       1.65     15608.0  United Kingdom
# 297505  08/11/2011 09:56       2.95     15608.0  United Kingdom

# %% [markdown]
# ### Quiz 22386 และ 85099B คือสินค้าอะไร

# %%
set(data[data['StockCode']=='22386']['Description'])
# Out:
# {'JUMBO BAG PINK POLKADOT'}

# %%
set(data[data['StockCode']=='85099B']['Description'])
# Out:
# {'JUMBO BAG RED RETROSPOT'}

# %% [markdown]
# #Homework1 หา Frequent Item Set และ Assosiation Rules
# -  ของช่วงเวลา Chrismas & New year (1 Dec-31 Dec) [หนามเตย]
# -  ของประเทศในทวีป Europe [จจ]
# -  ของช่วงเวลา ตรุษจีนในทวีป Asia(15 Jan-15 Feb) [ใบเตย]
# -  ของช่วงเวลา Chrismas & New year ในทวีป Europe (1 Dec-31 Dec) [พิม]
# -  ของวันวาเลนไทน์ [ตุนนี่]
# -  โดยจัดกลุ่มตามประเทศ+เดือน [พิมจ๊อก]

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom
# ...                  ...        ...         ...             ...
# 541904  12/09/2011 12:50       0.85     12680.0          France
# 541905  12/09/2011 12:50       2.10     12680.0          France
# 541906  12/09/2011 12:50       4.15     12680.0          France
# 541907  12/09/2011 12:50       4.15     12680.0          France
# 541908  12/09/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# ##จัดการข้อมูล

# %% [markdown]
# แยกวัน เดือน ปี เวลา

# %%
import pandas as pd

data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'], format='%m/%d/%Y %H:%M')

# Create new columns for day, month, year, and time
data['Day'] = data['InvoiceDate'].dt.day
data['Month'] = data['InvoiceDate'].dt.month
data['Year'] = data['InvoiceDate'].dt.year
data['Time'] = data['InvoiceDate'].dt.time

# Display the modified DataFrame
print(data.head())

# Drop the original
data.drop(columns=['InvoiceDate'], inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Day  Month  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom    1     12
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    1     12
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom    1     12
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    1     12
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    1     12
#
#    Year      Time
# 0  2010  08:26:00
# 1  2010  08:26:00
# 2  2010  08:26:00
# 3  2010  08:26:00
# 4  2010  08:26:00

# %% [markdown]
# ##1.ของช่วงเวลา Chrismas & New year (1 Dec-31 Dec)

# %%
import pandas as pd
import os
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/MyDrive/Mining'
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv(os.path.join(path,'/content/drive/MyDrive/Mining/reduced_marketbasket.csv'),encoding='latin-1')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-9b20d7d6b485> in <cell line: 1>()
# ----> 1 data = pd.read_csv(os.path.join(path,'/content/drive/MyDrive/Mining/reduced_marketbasket.csv'),encoding='latin-1')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1733                 if "b" not in mode:
#    1734                     mode += "b"
# -> 1735             self.handles = get_handle(
#    1736                 f,
#    1737                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854         if ioargs.encoding and "b" not in ioargs.mode:
#     855             # Encoding
# --> 856             handle = open(
#     857                 handle,
#     858                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Mining/reduced_marketbasket.csv'

# %%
data

# %%
# แปลงคอลัมน์ timestamp เป็น datetime
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])

# %%
# กรองข้อมูลตามช่วงเวลา Chrismas & New Year
start_date = '2010-12-01'
end_date = '2011-12-09'
data = data[(data['InvoiceDate'] >= start_date) & (data['InvoiceDate'] <= end_date)]

# %%
# แยกวันที่เป็นเดือน, วัน, และปีแยกกัน
data['month'] = data['InvoiceDate'].dt.month
data['day'] = data['InvoiceDate'].dt.day
data['year'] = data['InvoiceDate'].dt.year

# %%
#เช็ค
data[['InvoiceDate', 'month', 'day', 'year']].head()

# %%
# แปลงข้อมูลเป็น Transaction List
transactions= data.groupby('InvoiceNo')['StockCode'].apply(list)

# %%
# ใช้ TransactionEncoder เพื่อแปลง Transaction List เป็นรูปแบบที่ mlxtend สามารถใช้ได้
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)

# %%
# หา Frequent Item Set ด้วย apriori algorithm
frequent_itemsets = apriori(df, min_support=0.04, use_colnames=True)

# %%
 #หา Association Rules
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)

# %%
# แสดง Frequent Item Set
print("Frequent Item Set:")
print(frequent_itemsets)

# %%
# แสดง Association Rules
print("\nAssociation Rules:")
print(rules)

# %%
data[data['StockCode']=='POST']

# %% [markdown]
# #ยังบ่เสร็จ

# %% [markdown]
# ##2.ของประเทศในทวีป Europe

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/MyDrive/BSC_DPDM23'

# %%
data = pd.read_csv(os.path.join(path,'reduced_marketbasket.csv'),encoding='latin-1')

# %%
data

# %%
import pandas as pd

data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'], format='%m/%d/%Y %H:%M')

# Create new columns for day, month, year, and time
data['Day'] = data['InvoiceDate'].dt.day
data['Month'] = data['InvoiceDate'].dt.month
data['Year'] = data['InvoiceDate'].dt.year
data['Time'] = data['InvoiceDate'].dt.time

# Display the modified DataFrame
print(data.head())

# Drop the original
data.drop(columns=['InvoiceDate'], inplace=True)

# %%
set(data['Country'])

# %%
data_EU_country = ['Austria','Belgium','Cyprus','Channel Islands','Czech Republic','Denmark','EIRE','European Community',
              'Finland','France','Germany','Greece','Iceland','Italy','Lithuania','Malta','Netherlands',
              'Norway','Poland','Portugal','Spain','Sweden','Switzerland','United Kingdom']

# %%
dataEU = data[data['Country']==""]
for i in range(len(data_EU_country)):
  x = data[data['Country']==data_EU_country[i]]
  dataEU=pd.concat([x,dataEU])

# %%
len(set(dataEU['Country']))

# %%
dataEU

# %%
dataEU.groupby('InvoiceNo')['StockCode'].apply(list)

# %%
transactions = dataEU.groupby('InvoiceNo')['StockCode'].apply(list)

# %%
# !pip install apyori

# %%
from apyori import apriori

# %%
apriori(transactions,min_support = 0.053)

# %%
list(apriori(transactions,min_support = 0.053))

# %%
frequentItemsets = list(apriori(transactions,min_support = 0.053))
frequentItemsets

# %%
len(frequentItemsets)

# %%
frequentItemsets[0]

# %%
frequentItemsets[0][0]

# %%
dir(frequentItemsets[0][0])

# %%
frequentItemsets[0][0].__len__()

# %%
min_sup = 0.032

frequentItemsets = list(apriori(transactions,min_support = min_sup))
for i in frequentItemsets:
    if i[0].__len__()>1:
        print('yes')
        print(i)

# %%
set(dataEU[(dataEU['StockCode']=='85099B')]['Description'])

# %%
set(dataEU[(dataEU['StockCode']=='22807')]['Description'])

# %%
transactions =dataEU.groupby(['Country', 'Year'])['StockCode'].apply(list)
min_sup = 0.4
frequentItemsets= list(apriori(transactions,min_support = min_sup))
for i in frequentItemsets:
    if i[0].__len__()>1:
        print('yes')
        print(i)

# %%
set(dataEU[(dataEU['StockCode']=='22423')]['Year'])

# %% [markdown]
# ##3.ของช่วงเวลา ตรุษจีนในทวีป Asia(15 Jan-15 Feb)

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/MyDrive/BSC_DPDM23'

# %%
data = pd.read_csv(os.path.join(path,'/content/drive/MyDrive/BSC_DPDM23/reduced_marketbasket.csv'),encoding='latin-1')

# %%
data

# %%
Asia = data[(data['Country']=='Bahrain') | (data['Country']=='Hong Kong')| (data['Country']=='Singapore') | (data['Country']=='Japan') | (data['Country']=='Israel') |
            (data['Country']=='Lebanon') | (data['Country']=='Saudi Arabia') | (data['Country']=='United Arab Emirates')]
Asia #แบ่งทวีปเอเชีย

# %%
# สร้าง DataFrame สำหรับเหตุการณ์ Chinese New Year
China = Asia[((Asia['Month'] == 1) & (Asia['Day'] >= 15) & (Asia['Day'] <= 31)) |
            ((Asia['Month'] == 2) & (Asia['Day'] <= 15))]

print(China)

# %%
trans_china = China.groupby('InvoiceNo')['Description'].apply(list).reset_index()
trans_china_apply = trans_chin['Description'].apply(lambda x: [str(item) for item in x])

# %%
trans_china_apply

# %%
min_sup = 0.33 #เปลี่ยนจนกว่าจะเจอ...

frequentItemset_China = list(apriori(trans_chin_apply, min_support = min_sup))
for i in frequentItemset_China:
    if i[0].__len__()>1:
        print('yes')
        print(i)

# %%
frequentItemset_China = list(apriori(trans_chin_apply, min_support=0.33))

for record in frequentItemset_China:
    if len(record.items) > 1:
        print('yes')
        print(f"Items: {', '.join(record.items)}")
        print(f"Support: {record.support:.4f} ({record.support*100:.2f}%)")

        for i, stat in enumerate(record.ordered_statistics, 1):
            items_base = 'None' if not stat.items_base else ', '.join(stat.items_base)
            items_add = ', '.join(stat.items_add)
            confidence = stat.confidence
            lift = stat.lift

            print(f"Rule {i}: ({items_base} -> {items_add} : Confidence={confidence:.4f}, Lift={lift:.4f})")
        print()

# %% [markdown]
# ##4.ของช่วงเวลา Chrismas & New year ในทวีป Europe (1 Dec-31 Dec)

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# Filter data for the Christmas & New Year period and European countries
european_countries = ['Austria', 'Belgium', 'Cyprus', 'Channel Islands', 'Czech Republic', 'Denmark', 'EIRE', 'European Community',
                      'Finland', 'France', 'Germany', 'Greece', 'Iceland', 'Italy', 'Lithuania', 'Malta', 'Netherlands',
                      'Norway', 'Poland', 'Portugal', 'Spain', 'Sweden', 'Switzerland', 'United Kingdom']

filtered_XmasAndNY = data[(data['Month'] == 12) & (data['Country'].isin(european_countries))]

# Create a binary DataFrame
basket = (filtered_XmasAndNY.groupby(['InvoiceNo', 'StockCode'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

basket_sets = basket.applymap(lambda x: 1 if x > 0 else 0)

# Run Apriori algorithm to find frequent item sets
frequent_itemsets = apriori(basket_sets, min_support=0.03, use_colnames=True)

# Display frequent item sets with more than one item
for itemset in frequent_itemsets[frequent_itemsets['itemsets'].apply(lambda x: len(x) > 1)].itertuples(index=False):
    print('yes')
    print(itemset)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# yes
# Pandas(support=0.04790221341261976, itemsets=frozenset({'22086', '22910'}))
# yes
# Pandas(support=0.03303600925008259, itemsets=frozenset({'22112', '22111'}))
# yes
# Pandas(support=0.036669970267591674, itemsets=frozenset({'22112', '22835'}))
# yes
# Pandas(support=0.036339610175090846, itemsets=frozenset({'22726', '22727'}))
# yes
# Pandas(support=0.030393128510075983, itemsets=frozenset({'22865', '22866'}))
# yes
# Pandas(support=0.030393128510075983, itemsets=frozenset({'22865', '22867'}))

# %%
# Coding find Product(Descripyion) with StockCode
def Product(x,y) :
  item =set(data[(data['StockCode']==x)|(data['StockCode']==y)]['Description'])
  return  item

# Create a summary table for comparing two products
product_pairs = [('22086', '22910'), ('22112', '22111'), ('22835', '22112'),
                 ('22726', '22727'), ('22865', '22866'), ('22865', '22867')]

# Create a DataFrame from the summary data
summary_df = pd.DataFrame(columns=['Product Pair', 'Support', 'Product 1 Description', 'Product 2 Description'])

# Populate the DataFrame
for product_pair in product_pairs:
    support = frequent_itemsets[
        frequent_itemsets['itemsets'] == frozenset(product_pair)]['support'].values[0]
    descriptions = Product(*product_pair)

    summary_df = summary_df.append({
        'Product Pair': product_pair,
        'Support': support,
        'Product 1 Description': descriptions.pop(),
        'Product 2 Description': descriptions.pop()
    }, ignore_index=True)

# Display the summary DataFrame
summary_df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <ipython-input-16-32d461a366fc>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# <ipython-input-16-32d461a366fc>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# <ipython-input-16-32d461a366fc>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# <ipython-input-16-32d461a366fc>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# <ipython-input-16-32d461a366fc>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
# <ipython-input-16-32d461a366fc>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_df = summary_df.append({
#      Product Pair   Support            Product 1 Description  \
# 0  (22086, 22910)  0.047902  PAPER CHAIN KIT 50'S CHRISTMAS
# 1  (22112, 22111)  0.033036       CHOCOLATE HOT WATER BOTTLE
# 2  (22835, 22112)  0.036670       CHOCOLATE HOT WATER BOTTLE
# 3  (22726, 22727)  0.036340        ALARM CLOCK BAKELIKE RED
# 4  (22865, 22866)  0.030393                              NaN
# 5  (22865, 22867)  0.030393          HAND WARMER BIRD DESIGN
#
#                Product 2 Description
# 0  PAPER CHAIN KIT VINTAGE CHRISTMAS
# 1       SCOTTIE DOG HOT WATER BOTTLE
# 2    HOT WATER BOTTLE I AM SO POORLY
# 3         ALARM CLOCK BAKELIKE GREEN
# 4             HAND WARMER OWL DESIGN
# 5                                NaN

# %% [markdown]
# ##5.ของวันวาเลนไทน

# %% [markdown]
# ##6.โดยจัดกลุ่มตามประเทศ+เดือน
